# %% [markdown]
# Neste notebook:
# * Avaliação de usuários por bucket
#     * em média, e mediana, em quantos buckets os utilizadores estão.
#     * quantos usuários novos estão em cada bucket e quantos não ocorrem
#
# Objetivo:
# * explorar caracteristicas dos datasets que permitam
#     * avaliar se o dataset é util para a análise
#     * escolher o número de buckets

# %% [markdown]
# Vamos definir o numero de itens em cada bucket como 50k

# %%
import os
import sys
sys.path.append(os.path.abspath('') + '/..')

# %%
from data import ImplicitData
from recommenders_implicit import ISGD  # ISGD framework, BISGD,
from eval_implicit import EvaluateAndStore # EvaluateAndStore para guardar estados do modelo e holdouts, a avaliação prequencial de ratings implicitos é opcional, , EvalHoldout
from dataset_evaluation_utils import * #get_interactions_info, plot_interactions_per_month, plot_user_presence_distribution, plot_n_users_per_bucket, plot_bucket_size

from datetime import datetime, timedelta

import joblib
import pandas as pd 
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_style('whitegrid')

# %% [markdown]
# ___
# # Movielens

# %%
# importa dataset 'movielensm1'
data = pd.read_csv("../datasets/ml1m_gte5.csv","\t")

# %%
data.shape
# Out:
# (226310, 3)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 226310 entries, 0 to 226309
# Data columns (total 3 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   UserID     226310 non-null  int64
#  1   ItemID     226310 non-null  int64
#  2   Timestamp  226310 non-null  int64
# dtypes: int64(3)
# memory usage: 5.2 MB

# %%
user_col = 'UserID'
item_col = 'ItemID'
dataset_name = 'movielens'

# %%
# Necessary Preprocess - create date from timestamp
data['date2'] = data['Timestamp'].apply(lambda x: datetime.fromtimestamp( x ) )
data['year'] = data['Timestamp'].apply(lambda x: datetime.fromtimestamp( x ).date().year)
data['month'] = data['Timestamp'].apply(lambda x: datetime.fromtimestamp( x ).date().month )
data['date'] = data[['year', 'month']].apply(lambda x: datetime.strptime( str(x[0])+'/'+str(x[1]), '%Y/%m' ) , axis=1)

# %%
# this lets me sample the first 10% of the dataset to avoid cold start.
# data.iloc[ :int( 0.1*data.shape[0] ) ]

# %% [markdown]
# ## Evaluating Time defined Buckets

# %% [markdown]
# How many interactions occur in each month?

# %%
plot_interactions_per_month(data=data, dataset_name='Movielens')

# %%
data['UserID'].value_counts() >= 5
# Out:
# 4277     True
# 4169     True
# 3032     True
# 4448     True
# 5100     True
#         ...
# 364     False
# 907     False
# 5155    False
# 4284    False
# 2524    False
# Name: UserID, Length: 6014, dtype: bool

# %%
k_core_users = data['UserID'].value_counts()[ data['UserID'].value_counts() >= 5 ].index

# %%
data = data.set_index('UserID').loc[k_core_users].reset_index()

# %%
data.shape
# Out:
# (225288, 7)

# %%
plot_interactions_per_month(data=data, dataset_name='Movielens')

# %%
# y_filter = (data['date'] < datetime.strptime('2018', '%Y')) & (datetime.strptime('2014', '%Y') <= data['date']) 
# y_filter = (data['date'] < datetime.strptime('2015-01', '%Y-%m')) & (datetime.strptime('2014-01', '%Y-%m') <= data['date']) 
y_filter = (data['date'] < datetime.strptime('2000-08', '%Y-%m')) & (datetime.strptime('2000-05', '%Y-%m') <= data['date'])

# %%
y_filter.sum()
# Out:
# 50742

# %%
data = data[y_filter.tolist()]

# %%
# number of remaining cases
data.shape[0]
# Out:
# 50742

# %%
plot_interactions_per_month(data=data, dataset_name=dataset_name)

# %% [markdown]
# Sampling the dataset - only most frequent users (overall)

# %%
user_freq_over_months = data.groupby(by=[user_col])['date'].nunique()

# %%
user_freq_over_months.plot(kind='hist',bins=user_freq_over_months.max())
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
_ = data.set_index(user_col).copy()

# %%
# frequency of users that occur every month:
_.reset_index()[user_col].value_counts().plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
u = data[user_col].value_counts().reset_index()['index'].to_list()

# %%
# to user, or not to use p ?
p = (data[user_col].value_counts()/data[user_col].shape[0])

# %%
prop = 0.75
s = round( len( u )*prop )

# %%
np.random.seed(42)
sampled_users = list( np.random.choice(u, size=s, replace=False, p=p) ) # , p=p

# %%
_.loc[sampled_users].shape
# Out:
# (45852, 6)

# %%
_.loc[sampled_users][item_col].nunique()
# Out:
# 2434

# %%
# frequency of users:
_.loc[sampled_users].reset_index()[user_col].value_counts().plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
# %%time
# ( data[:1000000].groupby(by=['user_id'])['date'].nunique() > 1 ).sum()
user_freq_over_months_sample = _.loc[sampled_users].reset_index().groupby(by=[user_col])['date'].nunique()
user_freq_over_months_sample.plot(kind='hist',bins=user_freq_over_months_sample.max())
# Out:
# CPU times: user 66.3 ms, sys: 561 µs, total: 66.9 ms
# Wall time: 64.8 ms
# <AxesSubplot:ylabel='Frequency'>

# %%
data[user_col].nunique(), data[item_col].nunique() # original number of users, original number of items
# Out:
# (1427, 2492)

# %%
# _.loc[freq_users].reset_index()['user_id'].nunique(), _.loc[freq_users].reset_index()['item_id'].nunique() # sample number of users, and of items
_.loc[sampled_users].reset_index()[user_col].nunique(), _.loc[sampled_users].reset_index()[item_col].nunique() # sample number of users, and of items
# Out:
# (1070, 2434)

# %%
# %%time
# plot_interactions_per_month(data=_.loc[freq_users].reset_index(), dataset_name=dataset_name)
plot_interactions_per_month(data=_.loc[sampled_users].reset_index(), dataset_name=dataset_name)

# %%
USE_THRESHOLD = False
# all users 0.303427
# USING prop = 0.75 , .305128
# USING prop = 0.5, 0.315315

if USE_THRESHOLD: 
    data = _.loc[sampled_users].reset_index()
    data = data.sort_values(by=['Timestamp'])
    print(data.shape[0])
else:
    print(data.shape[0])
# new sample
data.to_csv('output/movielens_dump/sampled_movielens.csv', index=False)
# Out:
# 50742

# %% [markdown]
# How many interactions occur in each month / year?

# %%
interactions_per_month = data.groupby(by=['date']).count().iloc[:, 0]
interactions_per_month.name = 'count'
interactions_per_month=interactions_per_month.reset_index()

# %%
# %%time
plot_interactions_per_month(data=data, dataset_name=dataset_name)
# Out:
# CPU times: user 217 ms, sys: 0 ns, total: 217 ms
# Wall time: 420 ms

# %% [markdown]
# What is the user presence distribution based on month, quarter, and semester?

# %%
# %%time
# 3min 16s
user_presence_df, user_month_interactions = get_interactions_info(data=data, user_col=user_col)

# new sample
user_presence_df.to_csv('output/movielens_dump/sample_user_presence_df.csv', index=False)
user_month_interactions.to_csv('output/movielens_dump/sample_user_month_interactions.csv', index=False)
# Out:
# 0.0 %
# CPU times: user 4.59 s, sys: 9.1 ms, total: 4.6 s
# Wall time: 4.89 s

# %%
user_presence_df.head()
# Out:
#    UserID  month_%
# 0    5493    0.875
# 1    5841    0.750
# 2    4448    0.750
# 3    5689    0.750
# 4    5359    0.750

# %%
# plotting user frequency distribution
plot_user_presence_distribution(user_presence_df, dataset_name=dataset_name)

# %% [markdown]
# How many examples are there per quarter and semester?

# %%
# plot_interactions_per_qns(user_interactions=user_trimestre_interactions, date_range=trimestres, dataset_name=dataset_name, type_of_range='quarter')

# %%
# plot_interactions_per_qns(user_interactions=user_semestre_interactions, date_range=semestres, dataset_name=dataset_name, type_of_range='semester')

# %% [markdown]
# How many FREQUENT users (occur in 80% or more intervals) exist?

# %%
# defining threshold
frequency_threshold = 1

# %%
# frequent_users_month, frequent_users_trimestre, frequent_users_semestre = get_frequent_users(user_presence_df, frequency_threshold=frequency_threshold)
frequent_users_month = get_frequent_users(user_presence_df, frequency_threshold=frequency_threshold)
# Out:
# 0 users of 4181 (0.0%) occurr in 100% or more months.

# %%
# old huge sample
# joblib.dump(frequent_users_month, 'output/amazonbooks_dump/frequent_users_month.joblib')

# new sample
joblib.dump(frequent_users_month, 'output/movielens_dump/sample_frequent_users_month.joblib')
# Out:
# ['output/movielens_dump/sample_frequent_users_month.joblib']

# %% [markdown]
# ## Evaluating Interactions 50E3 sized Buckets

# %%
n_iter_bucket = 50E3

interval_start, interval_end = get_bucket_intervals(data, n_iter_bucket)

# %% [markdown]
# How many users per bucket?

# %%
plot_users_per_fixed_bucket(data, 'UserID', interval_start, interval_end)

# %% [markdown]
# How many FREQUENT users (occur in 80% or more intervals) exist?

# %%
user_bucket_interactions_df, dates_fixed_buckets_df = get_fixed_buckets_info(data, 'UserID', interval_start, interval_end)

# %%
frequency_threshold = 0.8

# %%
frequent_users_bucket = get_frequent_users_fixed_buckets(user_bucket_interactions_df, frequency_threshold)
# Out:
# 83 users of 6014 (1.38%) occur in 80.0% or more buckets.

# %% [markdown]
# In median terms, how many times FREQUENT users appear in each bucket?

# %%
freq_user_bucket_info = get_frequent_user_statistics(user_bucket_interactions_df, frequent_users_bucket)

# %%
freq_user_bucket_info['median_freq_user_interactions'].plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
freq_user_bucket_info['freq_users_at_least_1_interaction'].plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
# frequent users interactions per bucket
plot_user_interactions_per_bucket(user_bucket_interactions_df, frequent_users_bucket)

# %% [markdown]
# Which timestamps occur in each bucket?

# %%
plot_timestamps_per_bucket(dates_fixed_buckets_df)

# %% [markdown]
# ___
# ## Store Buckets

# %%
num_factors = 160
num_iter = 8
learn_rate = 0.1
regularization = 0.4
num_nodes = 8

# %%
# transforma interações em objeto que contem mappings usuário-itens e item-usuários, contém também métodos de suporte.
# recebe listas
# stream = ImplicitData(data['UserID'].to_list(), data['ItemID'].to_list())
stream = ImplicitData(data['UserID'], data['ItemID'])

empty_stream = ImplicitData([], [])

# %%
# O modelo não pode conter o stream, deve ser iniciado com uma lista vazia
# Se o stream for passado, ao excluir itens conhecidos o recall é sempre 0. Ao permitir a recomendação de itens já vistos, o recall não é 0.
model = ISGD(empty_stream, num_factors, num_iter, learn_rate = learn_rate, u_regularization = regularization, i_regularization = regularization, random_seed = 10)

# %%
# criamos instancia de EvaluateAndStore para criar holdouts com o método EvaluateAndStore
n_holdouts = int( data.shape[0]/n_iter_bucket )
eval_movielens = EvaluateAndStore(model=model, data=stream, n_holdouts=n_holdouts, metrics=["Recall@N"], N_recommendations=20, seed=42)

# %%
# %%time
# interações de 0 a 100 são usadas para pre treino. 
# count define numero de interações a serem usadas.
# holdouts e checkpoints são 
# store_only - somente guarda holdouts, não faz avaliação prequencial.
# default_user - Somente usado quando store_only = False durante avaliação prequencial.
_ = eval_movielens.EvaluateAndStore(start_eval=0, count=stream.size, store_only=True) # 1:40 min
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <timed exec> in <module>
#
# ~/streamRec-forgetting/notebooks/../eval_implicit/EvaluateAndStore.py in EvaluateAndStore(self, start_eval, count, store_only, default_user)
#      53             # else, use interaction for training
#      54             else:
# ---> 55                 self.model.IncrTrain(uid, iid) # perform incremental training
#      56
#      57             if (checkpoint_count[1] >= checkpoint_size): # if the number of interactions exceedes the size of each checkpoint interval
#
# ~/streamRec-forgetting/notebooks/../recommenders_implicit/ISGD.py in IncrTrain(self, user, item, update_users, update_items, n_times)
#      60         """
#      61
# ---> 62         user_id, item_id = self.data.AddFeedback(user, item)
#      63
#      64         if len(self.user_factors) == self.data.maxuserid:
#
# ~/streamRec-forgetting/notebooks/../data/implicit_data.py in AddFeedback(self, user, item)
#      82         self.userindices = np.append(self.userindices, user_id)
#      83         # if item not in self.itemset:
# ---> 84         if not np.isin(item, self.itemset, True):
#      85             self.itemset = np.append(self.itemset, item)
#      86             self.maxitemid = self.maxitemid + 1
#
# <__array_function__ internals> in isin(*args, **kwargs)
#
# ~/.virtualenvs/dissertacao/lib/python3.6/site-packages/numpy/lib/arraysetops.py in isin(element, test_elements, assume_unique, invert)
#     706     element = np.asarray(element)
#     707     return in1d(element, test_elements, assume_unique=assume_unique,
# --> 708                 invert=invert).reshape(element.shape)
#     709
#     710
#
# <__array_function__ internals> in in1d(*args, **kwargs)
#
# ~/.virtualenvs/dissertacao/lib/python3.6/site-packages/numpy/lib/arraysetops.py in in1d(ar1, ar2, assume_unique, invert)
#     590     # here. The values from the first array should always come before
#     591     # the values from the second array.
# --> 592     order = ar.argsort(kind='mergesort')
#     593     sar = ar[order]
#     594     if invert:
#
# KeyboardInterrupt:

# %%
plot_bucket_size(eval_object=eval_movielens, dataset_name='movielens', filename='movielens_bucket_size.png')

# %%
plot_n_users_per_bucket(eval_object=eval_movielens, dataset_name='movielens', filename='movielens_user_per_bucket.png')

# %%
movielens_ubm = get_bucket_map(eval_object=eval_movielens)
movielens_median_user_presence = median_user_presence_per_bucket(eval_object=eval_movielens, user_bucket_map=movielens_ubm)
print( movielens_median_user_presence )
store_user_presence(dataset_name='movielens', median_user_presence=movielens_median_user_presence)

# %%
joblib.dump(movielens_ubm, 'output/joblib_bucket_info_dump/movielens_ubm', compress=True)
# Out:
# ['output/joblib_bucket_info_dump/movielens_ubm']

# %% [markdown]
# ___
